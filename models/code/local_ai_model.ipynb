# %%
import os
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv10n model
model = YOLO("../weight/best.pt")

# %%
# # 이미지파일 경로 표시
# source = "../image/thief.jpg"

# # 예측모델 구동
# results = model(source=source, save=True)

# %%
# 카메라 켜기
cap = cv2.VideoCapture(0)
# 웹캠 오류 처리
if not cap.isOpened():
    print("camera open failed")
    exit()

# %%
# 비디오 저장 설정
output_filename = '../result/video/output_result.mp4'
fourcc = cv2.VideoWriter_fourcc(*'XVID')
fps = 20.0
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_filename, fourcc, fps, (frame_width, frame_height))
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        # YOLO 추론
        results = model(frame)

        # 결과 프레임 (Bounding Box 포함)
        annotated_frame = results[0].plot()

        # 화면 출력
        cv2.imshow('YOLO Detection', annotated_frame)

        # 파일 저장
        out.write(annotated_frame)

        # 종료 키
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
finally:        
    # 자원 해제
    cap.release()
    out.release()
    cv2.destroyWindow("YOLO Detection")
# Out:
# 0: 384x640 1 Person, 67.0ms
# Speed: 5.2ms preprocess, 67.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Persons, 66.6ms
# Speed: 3.7ms preprocess, 66.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Person, 1 Persona, 48.7ms
# Speed: 2.5ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Persons, 1 Persona, 44.5ms
# Speed: 2.0ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Person, 1 Persona, 44.5ms
# Speed: 1.9ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Person, 1 Persona, 74.7ms
# Speed: 6.1ms preprocess, 74.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Person, 1 Persona, 48.2ms
# Speed: 1.9ms preprocess, 48.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 2025-07-10 10:20:38.179 Python[28237:634215] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-07-10 10:20:38.179 Python[28237:634215] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 2 Persons, 1 Persona, 50.6ms
# Speed: 2.2ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Person, 2 Personas, 45.7ms
# Speed: 1.9ms preprocess, 45.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Persons, 2 Personas, 42.2ms
# Speed: 1.9ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.8ms
# Speed: 1.9ms preprocess, 47.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.5ms
# Speed: 2.0ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.8ms
# Speed: 1.9ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.9ms
# Speed: 2.4ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.5ms
# Speed: 1.9ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 66.1ms
# Speed: 3.0ms preprocess, 66.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.2ms
# Speed: 1.9ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.7ms
# Speed: 2.0ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.2ms
# Speed: 1.8ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.7ms
# Speed: 1.9ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 46.3ms
# Speed: 2.0ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 51.1ms
# Speed: 2.0ms preprocess, 51.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.5ms
# Speed: 1.8ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 46.8ms
# Speed: 1.9ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.9ms
# Speed: 1.8ms preprocess, 45.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.8ms
# Speed: 1.8ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Person, 2 Personas, 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.3ms
# Speed: 2.2ms preprocess, 45.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.3ms
# Speed: 2.1ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.2ms
# Speed: 1.9ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.2ms
# Speed: 2.0ms preprocess, 47.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.1ms
# Speed: 2.3ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.4ms
# Speed: 1.9ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.8ms
# Speed: 2.0ms preprocess, 47.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.3ms
# Speed: 1.9ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 48.8ms
# Speed: 1.8ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Personas, 44.6ms
# Speed: 2.4ms preprocess, 44.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Personas, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Personas, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.2ms
# Speed: 2.3ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 48.2ms
# Speed: 2.5ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 46.1ms
# Speed: 2.3ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.2ms
# Speed: 1.9ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.5ms
# Speed: 2.2ms preprocess, 43.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.8ms
# Speed: 1.9ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 46.2ms
# Speed: 1.9ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.7ms
# Speed: 1.9ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 48.0ms
# Speed: 2.4ms preprocess, 48.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.5ms
# Speed: 2.5ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 48.4ms
# Speed: 1.9ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.4ms
# Speed: 2.0ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.8ms
# Speed: 1.8ms preprocess, 45.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.8ms
# Speed: 2.5ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.5ms
# Speed: 2.3ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 49.7ms
# Speed: 1.9ms preprocess, 49.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.8ms
# Speed: 1.9ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.4ms
# Speed: 1.8ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 45.4ms
# Speed: 1.9ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 42.8ms
# Speed: 1.9ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.2ms
# Speed: 1.8ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.4ms
# Speed: 1.8ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 48.0ms
# Speed: 1.7ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Personas, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
